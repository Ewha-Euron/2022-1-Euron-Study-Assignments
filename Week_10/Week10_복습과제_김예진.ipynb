# %%
#IMPORT THE LIBRARIES....
import numpy as np # linear algebra....
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)....
from matplotlib import pyplot as plt #Visualization of the data....
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all"

#Useful machine learning libraries....
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,BaggingClassifier,ExtraTreesClassifier,GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, learning_curve ,KFold
from sklearn.metrics import roc_curve,accuracy_score,f1_score,auc,confusion_matrix,roc_auc_score
from xgboost.sklearn import XGBClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
df=pd.read_csv("winequality-red.csv")
df.head().style.background_gradient(cmap='cool')
# Out:
# <style  type="text/css" >
# #T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col0,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col2,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col3,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col5,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col6,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col9,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col10,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col11,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col2,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col7,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col11,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow2_col11,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow3_col1,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow3_col3,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow3_col4,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow3_col8,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow4_col0,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow4_col2,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow4_col3,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow4_col5,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow4_col6,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow4_col9,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow4_col10,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow4_col11{
#             background-color:  #00ffff;
#             color:  #000000;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col1,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow4_col1{
#             background-color:  #b34cff;
#             color:  #000000;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col4,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow4_col4{
#             background-color:  #0bf4ff;
#             color:  #000000;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col7,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow4_col7{
#             background-color:  #d52aff;
#             color:  #f1f1f1;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col8,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col1,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col3,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col4,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col5,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col6,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col9,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col10,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow2_col10,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow3_col0,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow3_col2,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow3_col7,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow3_col10,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow3_col11,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow4_col8{
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col0,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow2_col0{
#             background-color:  #1ae5ff;
#             color:  #000000;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col8{
#             background-color:  #1de2ff;
#             color:  #000000;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow2_col1{
#             background-color:  #cc33ff;
#             color:  #f1f1f1;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow2_col2{
#             background-color:  #12edff;
#             color:  #000000;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow2_col3{
#             background-color:  #926dff;
#             color:  #000000;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow2_col4{
#             background-color:  #bd42ff;
#             color:  #000000;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow2_col5,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow2_col8{
#             background-color:  #49b6ff;
#             color:  #000000;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow2_col6{
#             background-color:  #9b64ff;
#             color:  #000000;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow2_col7,#T_36575a23_cf53_11ec_b53e_e884a540bb4erow3_col9{
#             background-color:  #2ad5ff;
#             color:  #000000;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow2_col9{
#             background-color:  #bf40ff;
#             color:  #000000;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow3_col5{
#             background-color:  #6d92ff;
#             color:  #000000;
#         }#T_36575a23_cf53_11ec_b53e_e884a540bb4erow3_col6{
#             background-color:  #c936ff;
#             color:  #f1f1f1;
#         }</style><table id="T_36575a23_cf53_11ec_b53e_e884a540bb4e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >fixed acidity</th>        <th class="col_heading level0 col1" >volatile acidity</th>        <th class="col_heading level0 col2" >citric acid</th>        <th class="col_heading level0 col3" >residual sugar</th>        <th class="col_heading level0 col4" >chlorides</th>        <th class="col_heading level0 col5" >free sulfur dioxide</th>        <th class="col_heading level0 col6" >total sulfur dioxide</th>        <th class="col_heading level0 col7" >density</th>        <th class="col_heading level0 col8" >pH</th>        <th class="col_heading level0 col9" >sulphates</th>        <th class="col_heading level0 col10" >alcohol</th>        <th class="col_heading level0 col11" >quality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_36575a23_cf53_11ec_b53e_e884a540bb4elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col0" class="data row0 col0" >7.400000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col1" class="data row0 col1" >0.700000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col2" class="data row0 col2" >0.000000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col3" class="data row0 col3" >1.900000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col4" class="data row0 col4" >0.076000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col5" class="data row0 col5" >11.000000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col6" class="data row0 col6" >34.000000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col7" class="data row0 col7" >0.997800</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col8" class="data row0 col8" >3.510000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col9" class="data row0 col9" >0.560000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col10" class="data row0 col10" >9.400000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow0_col11" class="data row0 col11" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_36575a23_cf53_11ec_b53e_e884a540bb4elevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col0" class="data row1 col0" >7.800000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col1" class="data row1 col1" >0.880000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col3" class="data row1 col3" >2.600000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col4" class="data row1 col4" >0.098000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col5" class="data row1 col5" >25.000000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col6" class="data row1 col6" >67.000000</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col7" class="data row1 col7" >0.996800</td>
#                         <td id="T_36575a23_cf53_11ec_b53e_e884a540bb4erow1_col8" class="data row1 col8" >3.200000</td>

# %%
#Its always better to have a copy of you dataset.....
df1=df.copy()

# %% [markdown]
# ## Meta Information Of The Dataset

# %%
df.shape
# Out:
# (1599, 12)

# %%
numerical_features = [feature for feature in df.columns if df[feature].dtypes != 'O']
print('Number of numerical variables: ', len(numerical_features))
print('-'*100)
print('Numerical Variables Column: ',numerical_features)
# Out:
# Number of numerical variables:  12
# ----------------------------------------------------------------------------------------------------
# Numerical Variables Column:  ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %%
df.ndim
# Out:
# 2

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1599, step=1)

# %%
df.size
# Out:
# 19188

# %%
def memory_use():
    print('\033[1m'+'Memory used by all colomns in bytes'+'\033[0m')

# %%
k = df.memory_usage()
print(k,'bytes'+'\n')
# Out:
# Index                     128
# fixed acidity           12792
# volatile acidity        12792
# citric acid             12792
# residual sugar          12792
# chlorides               12792
# free sulfur dioxide     12792
# total sulfur dioxide    12792
# density                 12792
# pH                      12792
# sulphates               12792
# alcohol                 12792
# quality                 12792
# dtype: int64 bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ## Finding The Unique values

# %%
from IPython.core.display import HTML
def multi_table(table_list):
    ''' Acceps a list of IpyTable objects and returns a table which contains each IpyTable in a cell
    '''
    return HTML(
        '<table><tr style="background-color:white;">' + 
        ''.join(['<td>' + table._repr_html_() + '</td>' for table in table_list]) +
        '</tr></table>')

# %%
df_nunique = {var: pd.DataFrame(df[var].value_counts()) 
              for var in {'quality'}}
multi_table([df_nunique['quality'].style.background_gradient(cmap='cool')])
# Out:
# <table><tr style="background-color:white;"><td><style  type="text/css" >
# #T_64a4c692_cf62_11ec_b3a1_e884a540bb4erow0_col0{
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }#T_64a4c692_cf62_11ec_b3a1_e884a540bb4erow1_col0{
#             background-color:  #ef10ff;
#             color:  #f1f1f1;
#         }#T_64a4c692_cf62_11ec_b3a1_e884a540bb4erow2_col0{
#             background-color:  #48b7ff;
#             color:  #000000;
#         }#T_64a4c692_cf62_11ec_b3a1_e884a540bb4erow3_col0{
#             background-color:  #10efff;
#             color:  #000000;
#         }#T_64a4c692_cf62_11ec_b3a1_e884a540bb4erow4_col0{
#             background-color:  #03fcff;
#             color:  #000000;
#         }#T_64a4c692_cf62_11ec_b3a1_e884a540bb4erow5_col0{
#             background-color:  #00ffff;
#             color:  #000000;
#         }</style><table id="T_64a4c692_cf62_11ec_b3a1_e884a540bb4e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >quality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_64a4c692_cf62_11ec_b3a1_e884a540bb4elevel0_row0" class="row_heading level0 row0" >5</th>
#                         <td id="T_64a4c692_cf62_11ec_b3a1_e884a540bb4erow0_col0" class="data row0 col0" >681</td>
#             </tr>
#             <tr>
#                         <th id="T_64a4c692_cf62_11ec_b3a1_e884a540bb4elevel0_row1" class="row_heading level0 row1" >6</th>
#                         <td id="T_64a4c692_cf62_11ec_b3a1_e884a540bb4erow1_col0" class="data row1 col0" >638</td>
#             </tr>
#             <tr>
#                         <th id="T_64a4c692_cf62_11ec_b3a1_e884a540bb4elevel0_row2" class="row_heading level0 row2" >7</th>
#                         <td id="T_64a4c692_cf62_11ec_b3a1_e884a540bb4erow2_col0" class="data row2 col0" >199</td>
#             </tr>
#             <tr>
#                         <th id="T_64a4c692_cf62_11ec_b3a1_e884a540bb4elevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_64a4c692_cf62_11ec_b3a1_e884a540bb4erow3_col0" class="data row3 col0" >53</td>
#             </tr>
#             <tr>
#                         <th id="T_64a4c692_cf62_11ec_b3a1_e884a540bb4elevel0_row4" class="row_heading level0 row4" >8</th>
#                         <td id="T_64a4c692_cf62_11ec_b3a1_e884a540bb4erow4_col0" class="data row4 col0" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_64a4c692_cf62_11ec_b3a1_e884a540bb4elevel0_row5" class="row_heading level0 row5" >3</th>
#                         <td id="T_64a4c692_cf62_11ec_b3a1_e884a540bb4erow5_col0" class="data row5 col0" >10</td>
#             </tr>
#     </tbody></table></td></tr></table>

# %% [markdown]
# ## Finding The Missing Values

# %%
df.isnull().sum().sort_values()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## Finding The Duplicate Values and Dropping Them

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## Basic Statistics

# %%
round(df.describe(exclude = 'object'), 2).T.style.background_gradient(cmap='cool')
# Out:
# <style  type="text/css" >
# #T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow0_col0,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow1_col0,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow1_col7,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow2_col0,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow2_col1,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow2_col3,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow2_col4,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow2_col7,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow3_col0,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow4_col0,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow4_col1,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow4_col2,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow4_col3,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow4_col4,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow4_col5,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow4_col6,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow4_col7,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow5_col0,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow6_col0,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow7_col0,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow7_col2,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow7_col7,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow8_col0,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow9_col0,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow10_col0,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow11_col0{
#             background-color:  #00ffff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow0_col1{
#             background-color:  #2dd2ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow0_col2,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow0_col7,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow3_col1,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow3_col7,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow8_col6{
#             background-color:  #0df2ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow0_col3{
#             background-color:  #8c73ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow0_col4{
#             background-color:  #52adff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow0_col5{
#             background-color:  #34cbff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow0_col6{
#             background-color:  #25daff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow1_col1,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow1_col5,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow1_col6,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow9_col6{
#             background-color:  #02fdff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow1_col2,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow2_col2,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow2_col5,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow2_col6,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow8_col2,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow9_col2,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow9_col7{
#             background-color:  #01feff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow1_col3,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow1_col4,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow7_col6,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow8_col7,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow9_col1,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow9_col5{
#             background-color:  #03fcff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow3_col2,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow3_col6,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow7_col4,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow9_col3{
#             background-color:  #0af5ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow3_col3{
#             background-color:  #1be4ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow3_col4,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow8_col5{
#             background-color:  #15eaff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow3_col5{
#             background-color:  #0ef1ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow5_col1{
#             background-color:  #56a9ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow5_col2,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow5_col4{
#             background-color:  #50afff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow5_col3,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow7_col3,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow11_col1{
#             background-color:  #1ee1ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow5_col5{
#             background-color:  #5da2ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow5_col6{
#             background-color:  #55aaff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow5_col7{
#             background-color:  #3fc0ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow6_col1,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow6_col2,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow6_col4,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow6_col5,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow6_col6,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow6_col7,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow10_col3{
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow6_col3{
#             background-color:  #b649ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow7_col1{
#             background-color:  #04fbff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow7_col5,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow11_col2,#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow11_col7{
#             background-color:  #06f9ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow8_col1{
#             background-color:  #11eeff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow8_col3{
#             background-color:  #53acff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow8_col4{
#             background-color:  #24dbff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow9_col4{
#             background-color:  #05faff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow10_col1{
#             background-color:  #38c7ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow10_col2{
#             background-color:  #08f7ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow10_col4{
#             background-color:  #6e91ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow10_col5{
#             background-color:  #44bbff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow10_col6{
#             background-color:  #2cd3ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow10_col7{
#             background-color:  #0cf3ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow11_col3{
#             background-color:  #5ba4ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow11_col4{
#             background-color:  #39c6ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow11_col5{
#             background-color:  #27d8ff;
#             color:  #000000;
#         }#T_dfd2f033_cf6c_11ec_96c8_e884a540bb4erow11_col6{
#             background-color:  #18e7ff;
#             color:  #000000;
#         }</style><table id="T_dfd2f033_cf6c_11ec_96c8_e884a540bb4e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_headin

# %% [markdown]
# ## Feature Analysis & Also Finding Outliers

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Fixed Acidity Before Treating Oultier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["fixed acidity"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["fixed acidity"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Fixed Acidity Before Treating Oultier')
# (-0.5, 5.5, 4.034999999999999, 16.465)
# (2.6808483021557743, 17.819151697844227, 0.0, 0.3548613960030473)

# %%
df["Log_fixed acidity"]=np.log(df["fixed acidity"])

plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Fixed Acidity After Treating Outlier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_fixed acidity"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_fixed acidity"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Fixed Acidity After Treating Outlier')
# (-0.5, 5.5, 1.4640431632084923, 2.828332249512743)
# (1.3081175898196749, 2.98425782290156, 0.0, 2.640702879889384)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Volatile Acidity Before Treating Oultier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["volatile acidity"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["volatile acidity"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Volatile Acidity Before Treating Oultier')
# (-0.5, 5.5, 0.047, 1.653)
# (-0.09569062975368034, 1.7956906297536803, 0.0, 2.357570534337297)

# %%
df["Log_volatile acidity"]=np.log(df["volatile acidity"])

plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Volatitle After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_volatile acidity"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_volatile acidity"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Volatitle After Treating Outliers')
# (-0.5, 5.5, -2.2491479553620395, 0.5863092662008238)
# (-2.5265244461335117, 0.863685756972296, 0.0, 1.3038531632340873)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Citric Acidity', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["citric acid"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["citric acid"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Citric Acidity')
# (-0.5, 5.5, -0.05, 1.05)
# (-0.2024396646689328, 1.2024396646689328, 0.0, 3.244260485651214)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Residual Sugar Before Treating Oultier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["residual sugar"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["residual sugar"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Residual Sugar Before Treating Oultier')
# (-0.5, 5.5, 0.17000000000000004, 16.23)
# (-0.8842594798659709, 17.284259479865973, 0.0, 0.8969881157579599)

# %%
df["Log_residual sugar"]=np.log(df["residual sugar"])

plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Residual Sugar After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_residual sugar"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_residual sugar"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Residual Sugar After Treating Outliers')
# (-0.5, 5.5, -0.24767054263697766, 2.8831500509043524)
# (-0.5205328213637102, 3.1560123296310847, 0.0, 3.2303628496248566)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Chlorides Before Treating Oultier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["chlorides"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["chlorides"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Chlorides Before Treating Oultier')
# (-0.5, 5.5, -0.01795, 0.64095)
# (-0.056444044019206246, 0.6794440440192063, 0.0, 28.505935204737835)

# %%
df["Log_chlorides"]=np.log(df["chlorides"])

plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Chlorides After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_chlorides"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_chlorides"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Chlorides After Treating Outliers')
# (-0.5, 5.5, -4.619358144663317, -0.296148804341362)
# (-4.881337738367757, -0.03416921063692177, 0.0, 2.3393932002985567)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Free Sulfurdioxide Before Treating Oultier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["free sulfur dioxide"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["free sulfur dioxide"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Free Sulfurdioxide Before Treating Oultier')
# (-0.5, 5.5, -2.5500000000000003, 75.55)
# (-10.694658476278263, 83.69465847627826, 0.0, 0.07226782327519196)

# %%
df["Log_free sulfur dioxide"]=np.log(df["free sulfur dioxide"])

plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Free Sulfurdioxide After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_free sulfur dioxide"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_free sulfur dioxide"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Free Sulfurdioxide After Treating Outliers')
# (-0.5, 5.5, -0.21383330595080277, 4.490499424966858)
# (-0.7469988499684044, 5.02366496898446, 0.0, 0.6120795898727687)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Total Sulfurdioxide Before Treating Oultier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["total sulfur dioxide"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["total sulfur dioxide"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Total Sulfurdioxide Before Treating Oultier')
# (-0.5, 5.5, -8.15, 303.15)
# (-34.19550720770688, 329.19550720770684, 0.0, 0.02001731682774437)

# %%
df["Log_total sulfur dioxide"]=np.log(df["total sulfur dioxide"])

plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Total Sulfurdioxide After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_total sulfur dioxide"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_total sulfur dioxide"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Total Sulfurdioxide After Treating Outliers')
# (-0.5, 5.5, 1.598026108283836, 5.860160049056651)
# (1.0433136223029034, 6.414872535037584, 0.0, 0.5736873792116851)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Density', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["density"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["density"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Density')
# (-0.5, 5.5, 0.989389, 1.004371)
# (0.9879319981815609, 1.0058280018184391, 0.0, 266.164872460653)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The pH', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["pH"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["pH"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The pH')
# (-0.5, 5.5, 2.6765000000000003, 4.0735)
# (2.555634187634965, 4.194365812365034, 0.0, 3.421459734751669)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Sulphates Before Treating Oultier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["sulphates"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["sulphates"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Sulphates Before Treating Oultier')
# (-0.5, 5.5, 0.2465, 2.0835)
# (0.11344863802041227, 2.2165513619795876, 0.0, 4.418315686507767)

# %%
df["Log_sulphates"]=np.log(df["sulphates"])

plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Sulphates After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_sulphates"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_sulphates"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Sulphates After Treating Outliers')
# (-0.5, 5.5, -1.198753114775689, 0.7832376708140232)
# (-1.3735377827538806, 0.9580223387922147, 0.0, 2.439048768832756)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Alcohol Before Treating Oultier', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["alcohol"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["alcohol"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Alcohol Before Treating Oultier')
# (-0.5, 5.5, 8.075000000000001, 15.225)
# (7.231425236428579, 16.068574763571423, 0.0, 0.7080828663610123)

# %%
df["Log_alcohol"]=np.log(df["alcohol"])
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Distribution Of The Alcohol After Treating Outliers', fontsize=30, fontweight='bold')

ax1 = fig.add_subplot(121)
ax1 = sns.boxplot(x=df["quality"], y=df["Log_alcohol"],palette="cool")
plt.axis('off')

ax2 = fig.add_subplot(122)
x=df["Log_alcohol"]
ax2 = sns.distplot(x)
plt.axis('off')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribution Of The Alcohol After Treating Outliers')
# (-0.5, 5.5, 2.099575230494161, 2.7300176883065204)
# (2.0213916915268415, 2.8082012272738397, 0.0, 7.190682039418455)

# %% [markdown]
# ## Feature Engineering & Feature Transformation

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('Before-Distribution Of The Quality', fontsize=30, fontweight='bold')
ax = sns.barplot(y = df['quality'].value_counts().values.tolist(), 
                      x = df['quality'].value_counts().index, palette="cool")
ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Text(0.5, 0.98, 'Before-Distribution Of The Quality')

# %%
bins = (2, 6.5, 8)
group_names = ['bad', 'good']
df['quality'] = pd.cut(df['quality'], bins = bins, labels = group_names)

#Feature Transformation...
df['quality'].replace({'bad':0, 'good':1}, inplace=True)

# %%
plt.rcParams['font.family'] = ['serif']
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
fig.suptitle('After-Distribution Of The Quality', fontsize=30, fontweight='bold')

ax = sns.barplot(y = df['quality'].value_counts().values.tolist(), 
                      x = df['quality'].value_counts().index, palette="cool")
ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Text(0.5, 0.98, 'After-Distribution Of The Quality')

# %% [markdown]
# ## Dropping The Redundant Columns

# %%
df.drop(columns = ['fixed acidity', 'volatile acidity','residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide','sulphates', 'alcohol'],axis=True,inplace =True)

# %%
df = df[['Log_fixed acidity','Log_volatile acidity','citric acid', 'Log_residual sugar', 'Log_chlorides',
       'Log_free sulfur dioxide', 'Log_total sulfur dioxide','density',
       'pH','Log_sulphates','Log_alcohol','quality']]

# %%
df.head().style.background_gradient(cmap='cool')
# Out:
# <style  type="text/css" >
# #T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col0,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col2,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col5,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col6,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col9,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col10,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col11,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col2,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col7,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col11,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow2_col11,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow3_col1,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow3_col4,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow3_col8,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow3_col11,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow4_col0,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow4_col2,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow4_col3,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow4_col4,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow4_col9,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow4_col10,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow4_col11{
#             background-color:  #00ffff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col1{
#             background-color:  #cc33ff;
#             color:  #f1f1f1;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col3,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow3_col3{
#             background-color:  #25daff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col4{
#             background-color:  #0cf3ff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col7,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow4_col7{
#             background-color:  #d52aff;
#             color:  #f1f1f1;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col8,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col1,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col3,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col4,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col5,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col6,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col9,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col10,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow2_col10,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow3_col0,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow3_col2,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow3_col7,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow3_col10,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow4_col8{
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col0,#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow2_col0{
#             background-color:  #20dfff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col8{
#             background-color:  #1de2ff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow2_col1{
#             background-color:  #df20ff;
#             color:  #f1f1f1;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow2_col2{
#             background-color:  #12edff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow2_col3{
#             background-color:  #aa55ff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow2_col4{
#             background-color:  #c33cff;
#             color:  #f1f1f1;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow2_col5{
#             background-color:  #609fff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow2_col6{
#             background-color:  #ae51ff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow2_col7{
#             background-color:  #2ad5ff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow2_col8{
#             background-color:  #49b6ff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow2_col9{
#             background-color:  #c43bff;
#             color:  #f1f1f1;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow3_col5{
#             background-color:  #8778ff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow3_col6{
#             background-color:  #d629ff;
#             color:  #f1f1f1;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow3_col9{
#             background-color:  #2ed1ff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow4_col1{
#             background-color:  #bf40ff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow4_col5{
#             background-color:  #34cbff;
#             color:  #000000;
#         }#T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow4_col6{
#             background-color:  #3dc2ff;
#             color:  #000000;
#         }</style><table id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Log_fixed acidity</th>        <th class="col_heading level0 col1" >Log_volatile acidity</th>        <th class="col_heading level0 col2" >citric acid</th>        <th class="col_heading level0 col3" >Log_residual sugar</th>        <th class="col_heading level0 col4" >Log_chlorides</th>        <th class="col_heading level0 col5" >Log_free sulfur dioxide</th>        <th class="col_heading level0 col6" >Log_total sulfur dioxide</th>        <th class="col_heading level0 col7" >density</th>        <th class="col_heading level0 col8" >pH</th>        <th class="col_heading level0 col9" >Log_sulphates</th>        <th class="col_heading level0 col10" >Log_alcohol</th>        <th class="col_heading level0 col11" >quality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col0" class="data row0 col0" >2.001480</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col1" class="data row0 col1" >-0.356675</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col2" class="data row0 col2" >0.000000</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col3" class="data row0 col3" >0.641854</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col4" class="data row0 col4" >-2.577022</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col5" class="data row0 col5" >2.397895</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col6" class="data row0 col6" >3.526361</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col7" class="data row0 col7" >0.997800</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col8" class="data row0 col8" >3.510000</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col9" class="data row0 col9" >-0.579818</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col10" class="data row0 col10" >2.240710</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow0_col11" class="data row0 col11" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4elevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col0" class="data row1 col0" >2.054124</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col1" class="data row1 col1" >-0.127833</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col3" class="data row1 col3" >0.955511</td>
#                         <td id="T_9b9dffc5_cf6d_11ec_9403_e884a540bb4erow1_col4" class="data

# %% [markdown]
# ## Checking The Relationship Between The Features

# %%
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
sns.pairplot(df,hue='quality',palette="cool")

# %%
background_color = "#ffffff"
fig = plt.figure(figsize=(15,7), facecolor=background_color)
sns.heatmap(df.corr(), annot=True,cmap = "cool",linewidths=2,linecolor = "white",cbar=True,annot_kws={"size":20})
# Out:
# <AxesSubplot:>

# %%
background_color = "#ffffff"
fig = plt.figure(figsize=(20,7), facecolor=background_color)
gs = fig.add_gridspec(1, 1)
ax0 = fig.add_subplot(gs[0, 0])
ax0.set_facecolor(background_color)
ax0.text(-1.1, 1.25, 'Correlation of Numerical Features with Target', fontsize=30, fontweight='bold')

chart_df = pd.DataFrame(df.corrwith(df['quality']))
chart_df.columns = ['corr']
sns.barplot(x=chart_df.index, y=chart_df['corr'], ax=ax0, palette='cool',edgecolor="black",linewidth=3)
ax0.grid(which='major', axis='x', zorder=0, color='#EEEEEE', linewidth=0.4)
ax0.grid(which='major', axis='y', zorder=0, color='#EEEEEE', linewidth=0.4)
ax0.set_ylabel('')

for s in ["top","right", 'left']:
    ax0.spines[s].set_visible(False)

plt.show()
# Out:
# Text(-1.1, 1.25, 'Correlation of Numerical Features with Target')
# <AxesSubplot:ylabel='corr'>
# Text(0, 0.5, '')

# %% [markdown]
# ## PCA Implementaion

# %%
#Feature Variables
x = df.drop('quality',axis=1)
#Target Variable
Y = df['quality']

x_train,x_test,Y_train,Y_test = train_test_split(x,Y,test_size = 0.25,random_state=44)

# %%
pca = PCA(n_components = None)
x_train = pca.fit_transform(x_train)
x_test = pca.transform(x_test)
explained_variance = pca.explained_variance_ratio_

print(explained_variance)
# Out:
# [5.85683601e-01 1.08632262e-01 9.84931406e-02 7.64697288e-02
#  6.04286021e-02 2.88574041e-02 2.50035979e-02 7.60575720e-03
#  4.80782361e-03 4.01777389e-03 3.08123008e-07]

# %%
len(explained_variance)
# Out:
# 11

# %%
print("Sorted List returned :")
print(sorted(explained_variance,reverse = True))
# Out:
# Sorted List returned :
# [0.5856836011918457, 0.10863226242281954, 0.09849314064863691, 0.07646972877373921, 0.06042860209659452, 0.02885740412589383, 0.02500359792368143, 0.0076057571967938905, 0.004807823609896302, 0.004017773887090503, 3.0812300822794386e-07]

# %%
background_color = "#ffffff"
fig = plt.figure(figsize=(20,7), facecolor=background_color)
plt.bar(range(11), explained_variance, alpha=0.5, align='center',label='Individual Explained Variance')
plt.ylabel('Explained Variance Ratio',fontsize = 18)
plt.xlabel('Principal Components',fontsize = 18)
plt.title('Explained Variance Ration vs Principal Components',fontsize = 25)
plt.legend(loc='best',fontsize = 18)
#plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# <BarContainer object of 11 artists>
# Text(0, 0.5, 'Explained Variance Ratio')
# Text(0.5, 0, 'Principal Components')
# Text(0.5, 1.0, 'Explained Variance Ration vs Principal Components')

# %%
# Applying PCA
from sklearn.decomposition import PCA
pca = PCA(n_components = 5)
x_train = pca.fit_transform(x_train)
x_test = pca.transform(x_test)
explained_variance = pca.explained_variance_ratio_
print(explained_variance)
# Out:
# [0.5856836  0.10863226 0.09849314 0.07646973 0.0604286 ]

# %% [markdown]
# ## Model Creation

# %%
# =============================================================================
# Cross validation on differnet set of algorithm!!!
# =============================================================================
################################################################
kfold = StratifiedKFold(n_splits=8,shuffle=True, random_state=42)


rs = 15
clrs = []

clrs.append(AdaBoostClassifier(random_state=rs))
clrs.append(GradientBoostingClassifier(random_state=rs))
clrs.append(RandomForestClassifier(random_state=rs))
clrs.append(DecisionTreeClassifier(random_state = rs))

cv_results = []
for clr in clrs :
    cv_results.append(cross_val_score(clr, x_train, Y_train , scoring = 'accuracy', cv = kfold, n_jobs=-1))

cv_means = []
cv_std = []
for cv_result in cv_results:
    cv_means.append(cv_result.mean())
    cv_std.append(cv_result.std())
    
cv_df = pd.DataFrame({"CrossVal_Score_Means":cv_means,"CrossValerrors": cv_std,"Algo":["RandomForestClassifier","AdaBoostClassifier","Gradient Boosting",'DecisionTreeClassifier']})
g = sns.barplot("CrossVal_Score_Means","Algo",data = cv_df,orient = "h",**{'xerr':cv_std},palette='cool',edgecolor="black",linewidth=3)
g.set_xlabel("Mean Accuracy",fontsize = 18)
g = g.set_title("Cross validation scores",fontsize = 24)
plt.figure(figsize = (15,7))
print(cv_df)
# Out:
# Text(0.5, 0, 'Mean Accuracy')
#    CrossVal_Score_Means  CrossValerrors                    Algo
# 0              0.838067        0.017989  RandomForestClassifier
# 1              0.849832        0.012887      AdaBoostClassifier
# 2              0.853746        0.016421       Gradient Boosting
# 3              0.822366        0.009710  DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train, Y_train)
Y_pred = dtc.predict(x_test)
confusion_matrix(Y_test, Y_pred)
# Out:
# DecisionTreeClassifier()
# array([[256,  37],
#        [ 30,  17]], dtype=int64)

# %%
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88       293
#            1       0.31      0.36      0.34        47
#
#     accuracy                           0.80       340
#    macro avg       0.60      0.62      0.61       340
# weighted avg       0.81      0.80      0.81       340

# %%
print(accuracy_score(Y_test, Y_pred))
# Out:
# 0.8029411764705883

# %% [markdown]
# ## Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV
grid_params = {
    'criterion' : ['gini', 'entropy'],
    'max_depth' : [3, 5, 7, 10],
    'min_samples_split' : range(2, 10, 1),
    'min_samples_leaf' : range(2, 10, 1)
}

grid_search = GridSearchCV(dtc, grid_params, cv = 5, n_jobs = -1, verbose = 1)
grid_search.fit(x_train, Y_train)
# Out:
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 2304 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 2560 out of 2560 | elapsed:    4.2s finished
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10],
#                          'min_samples_leaf': range(2, 10),
#                          'min_samples_split': range(2, 10)},
#              verbose=1)

# %%
dtc = grid_search.best_estimator_
Y_pred = dtc.predict(x_test)

# %%
print(accuracy_score(Y_test, Y_pred))
# Out:
# 0.8676470588235294

# %%
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.8616343088959721

# %%
ada = AdaBoostClassifier(base_estimator = dtc)

parameters = {
    'n_estimators' : [50, 70, 90, 120, 180, 200],
    'learning_rate' : [0.001, 0.01, 0.1, 1, 10],
    'algorithm' : ['SAMME', 'SAMME.R']
}

grid_search = GridSearchCV(ada, parameters, n_jobs = -1, cv = 10, verbose = 1)
grid_search.fit(x_train, Y_train)
# Out:
# Fitting 10 folds for each of 60 candidates, totalling 600 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=-1)]: Done 498 tasks      | elapsed:   52.0s
# [Parallel(n_jobs=-1)]: Done 600 out of 600 | elapsed:  1.0min finished
# GridSearchCV(cv=10,
#              estimator=AdaBoostClassifier(base_estimator=DecisionTreeClassifier(criterion='entropy',
#                                                                                 max_depth=5,
#                                                                                 min_samples_leaf=7)),
#              n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.001, 0.01, 0.1, 1, 10],
#                          'n_estimators': [50, 70, 90, 120, 180, 200]},
#              verbose=1)

# %%
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 0.001, 'n_estimators': 180}
# 0.8665501844302078

# %% [markdown]
# ## Final Model

# %%
ada = AdaBoostClassifier(base_estimator = dtc, algorithm= "SAMME", learning_rate= 0.1, n_estimators= 90)
ada.fit(x_train, Y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME',
#                    base_estimator=DecisionTreeClassifier(criterion='entropy',
#                                                          max_depth=5,
#                                                          min_samples_leaf=7),
#                    learning_rate=0.1, n_estimators=90)

# %%
print(confusion_matrix(Y_test, Y_pred))
# Out:
# [[281  12]
#  [ 33  14]]

# %%
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.93       293
#            1       0.54      0.30      0.38        47
#
#     accuracy                           0.87       340
#    macro avg       0.72      0.63      0.65       340
# weighted avg       0.85      0.87      0.85       340

# %%
print(accuracy_score(Y_test, Y_pred))
# Out:
# 0.8676470588235294
